# %%
# %pylab inline

from TB.c import *

from ms_mint.io import ms_file_to_df

fn_mzXML = glob('./input/MTBLS1569/data/mzXML/T*.mzXML')

fn_mzML = glob('./input/MTBLS1569/data/mzML/T*.mzML')

fn_mzMLb = glob('./input/MTBLS1569/data/mzMLb/T*.mzMLb')

fn_feather_from_mzXML = glob('./input/MTBLS1569/data/feather/from_mzXML/T*feather')

fn_feather_from_mzML = glob('./input/MTBLS1569/data/feather/from_mzML/T*feather')

fn_parquet_trr = glob('./input/MTBLS1569/data/parquet/ThermoRawFileReader/T*parquet')

fn_parquet_mint = glob('./input/MTBLS1569/data/parquet/Mint/T*parquet')

len(fn_mzXML), len(fn_mzML), len(fn_feather_from_mzML), len(fn_feather_from_mzXML), len(fn_parquet_trr), len(fn_parquet_mint)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# (12, 12, 12, 12, 12, 12)

# %%
import ms_mint

# %%
version_str = ms_mint.__version__.split('+')[0]
version_str
# Out:
# 'v0.3.3'

# %%
NAME = f'{today()}-sw__MINT-{version_str}-benchmark'
NAME
# Out:
# '230822-sw__MINT-v0.3.3-benchmark'

# %%
FN_RESULTS = f"results/{NAME}__read-speed-results.csv"

# %% [markdown]
# # Show file content

# %%
df_XML          = ms_file_to_df('./input/MTBLS1569/data/mzXML/Tx_1h_R1.mzXML')
df_ML           = ms_file_to_df('./input/MTBLS1569/data/mzML/Tx_1h_R1.mzML')
df_MLb          = ms_file_to_df('./input/MTBLS1569/data/mzMLb/Tx_1h_R1.mzMLb')
df_parquet_trr  = ms_file_to_df('./input/MTBLS1569/data/parquet/ThermoRawFileReader/Tx_1h_R1.parquet')
df_parquet_mint = ms_file_to_df('./input/MTBLS1569/data/parquet/Mint/Tx_1h_R1.parquet')
df_f_from_ML    = ms_file_to_df('./input/MTBLS1569/data/feather/from_mzML/Tx_1h_R1.feather')
df_f_from_XML   = ms_file_to_df('./input/MTBLS1569/data/feather/from_mzXML/Tx_1h_R1.feather')

# %%
df_ML
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.865723   700.627380      10354
# 1994488     3813         1        +  1920.865723   725.641357       4503
# 1994489     3813         1        +  1920.865723   726.642029       3104
# 1994490     3813         1        +  1920.865723   734.585632       3774
# 1994491     3813         1        +  1920.865723  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_f_from_ML
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.865723   700.627380      10354
# 1994488     3813         1        +  1920.865723   725.641357       4503
# 1994489     3813         1        +  1920.865723   726.642029       3104
# 1994490     3813         1        +  1920.865723   734.585632       3774
# 1994491     3813         1        +  1920.865723  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_XML
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.869995   700.627380      10354
# 1994488     3813         1        +  1920.869995   725.641357       4503
# 1994489     3813         1        +  1920.869995   726.642029       3104
# 1994490     3813         1        +  1920.869995   734.585632       3774
# 1994491     3813         1        +  1920.869995  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_f_from_XML
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.869995   700.627380      10354
# 1994488     3813         1        +  1920.869995   725.641357       4503
# 1994489     3813         1        +  1920.869995   726.642029       3104
# 1994490     3813         1        +  1920.869995   734.585632       3774
# 1994491     3813         1        +  1920.869995  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_MLb
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.865723   700.627380      10354
# 1994488     3813         1        +  1920.865723   725.641357       4503
# 1994489     3813         1        +  1920.865723   726.642029       3104
# 1994490     3813         1        +  1920.865723   734.585632       3774
# 1994491     3813         1        +  1920.865723  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_parquet_trr
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1     None     0.202426    86.096466       1967
# 1              1         1     None     0.202426    88.075768       2904
# 2              1         1     None     0.202426    89.059700       2797
# 3              1         1     None     0.202426    95.085472       2667
# 4              1         1     None     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1     None  1920.865723   700.627380      10354
# 1994488     3813         1     None  1920.865723   725.641357       4503
# 1994489     3813         1     None  1920.865723   726.642029       3104
# 1994490     3813         1     None  1920.865723   734.585632       3774
# 1994491     3813         1     None  1920.865723  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_parquet_mint
# Out:
#          scan_id  ms_level polarity    scan_time           mz  intensity
# 0              1         1        +     0.202426    86.096466       1967
# 1              1         1        +     0.202426    88.075768       2904
# 2              1         1        +     0.202426    89.059700       2797
# 3              1         1        +     0.202426    95.085472       2667
# 4              1         1        +     0.202426   100.075706       2388
# ...          ...       ...      ...          ...          ...        ...
# 1994487     3813         1        +  1920.869995   700.627380      10354
# 1994488     3813         1        +  1920.869995   725.641357       4503
# 1994489     3813         1        +  1920.869995   726.642029       3104
# 1994490     3813         1        +  1920.869995   734.585632       3774
# 1994491     3813         1        +  1920.869995  1142.810669       2981
#
# [1994492 rows x 6 columns]

# %%
df_compare = pd.concat([df_ML.add_prefix('mzML_'), 
                        df_XML.add_prefix('mzXML_'), 
                        df_MLb.add_prefix('mzMLb_'), 
                        df_parquet_trr.add_prefix('Parquet_TRR'), 
                        df_parquet_mint.add_prefix('Parquet_Mint'), 
                        df_f_from_ML.add_prefix('Feather_')], axis=1)

# %%
df_compare.filter(regex='intensity').corr()
# Out:
#                        mzML_intensity  mzXML_intensity  mzMLb_intensity  \
# mzML_intensity                    1.0              1.0              1.0
# mzXML_intensity                   1.0              1.0              1.0
# mzMLb_intensity                   1.0              1.0              1.0
# Parquet_TRRintensity              1.0              1.0              1.0
# Parquet_Mintintensity             1.0              1.0              1.0
# Feather_intensity                 1.0              1.0              1.0
#
#                        Parquet_TRRintensity  Parquet_Mintintensity  \
# mzML_intensity                          1.0                    1.0
# mzXML_intensity                         1.0                    1.0
# mzMLb_intensity                         1.0                    1.0
# Parquet_TRRintensity                    1.0                    1.0
# Parquet_Mintintensity                   1.0                    1.0
# ...

# %% [markdown]
# # Get processing times

# %%
import time

# %%
n_files = 12

sets = [('mzXML', fn_mzXML), 
        ('mzML',  fn_mzML),
        ('mzMLb',  fn_mzMLb),
        ('parquet-TRR',  fn_parquet_trr),
        ('parquet-Mint',  fn_parquet_mint),
        ('feather-from-mzXML', fn_feather_from_mzXML),
        ('feather-from-mzML',  fn_feather_from_mzML), 
       ]                  

results = pd.DataFrame()
i = 0
for kind, fns in tqdm(sets):
    for fn in fns:
        for mode in ['Read only', 'Format']:
            print(fn)
            start = time.time()
            ms_file_to_df(fn, read_only = (mode=='Read only'))
            end = time.time()
            results.loc[i, ['File name', 'File format', 'Read time [s]', 'Mode']] = (fn, kind, end-start, mode)
            i += 1
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# ./input/MTBLS1569/data/mzXML/Tx_6h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R3.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R1.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R1.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R4.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R2.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_3h_R2.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R2.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_1h_R2.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R2.mzXML
# ./input/MTBLS1569/data/mzXML/Tx_6h_R2.mzXML
# ...

# %%
results['File size [MB]'] = results['File name'].apply(os.path.getsize)/1024/1024
results.to_csv(FN_RESULTS, index=False)

# %% [markdown]
# # Figure

# %%
from matplotlib import pyplot as plt

# %%
results = pd.read_csv(FN_RESULTS)
results
# Out:
#                                                      File name  \
# 0                  ./input/MTBLS1569/data/mzXML/Tx_6h_R4.mzXML
# 1                  ./input/MTBLS1569/data/mzXML/Tx_6h_R4.mzXML
# 2                  ./input/MTBLS1569/data/mzXML/Tx_3h_R4.mzXML
# 3                  ./input/MTBLS1569/data/mzXML/Tx_3h_R4.mzXML
# 4                  ./input/MTBLS1569/data/mzXML/Tx_3h_R3.mzXML
# ..                                                         ...
# 163  ./input/MTBLS1569/data/feather/from_mzML/Tx_3h_R3.feather
# 164  ./input/MTBLS1569/data/feather/from_mzML/Tx_1h_R1.feather
# 165  ./input/MTBLS1569/data/feather/from_mzML/Tx_1h_R1.feather
# 166  ./input/MTBLS1569/data/feather/from_mzML/Tx_1h_R3.feather
# 167  ./input/MTBLS1569/data/feather/from_mzML/Tx_1h_R3.feather
#
#            File format  Read time [s]       Mode  File size [MB]
# 0                mzXML       1.083316  Read only       40.337051
# 1                mzXML       1.558117     Format       40.337051
# ...

# %%
sns.set_context('paper')
#plt.style.use('fivethirtyeight')
g= sns.catplot(data=results, kind='bar', x='File format', y='Read time [s]', aspect=1.5, height=4, hue='Mode', dodge=False, alpha=1, hue_order=['Format', 'Read only'], legend=False)
#g.set(yscale="log")
g.set_xticklabels(rotation=30)
grid(lw=0.2)
legend(title='Mode', shadow=False)
tight_layout()
savefig('output/ms-file-formats-read-speed.svg')
show()
# Out:
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /tmp/ipykernel_2666089/3380930035.py:8: UserWarning: The figure layout has changed to tight
#   tight_layout()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your data should be in a DataFrame named "results"

plt.figure(figsize=(7, 3))

subplot(1,2,1)

sns.barplot(data=results, x='File format', y='Read time [s]', hue='Mode',
            dodge=False, alpha=1, hue_order=['Format', 'Read only'], ax=gca())

plt.title('File read time [s]')
plt.xticks(rotation=30)
plt.grid(lw=0.2)
plt.legend(title='Mode', shadow=False)
plt.annotate('a)', xy=(-0.1, 1.1), xycoords='axes fraction', fontsize=12, fontweight='bold')
plt.tight_layout()
sns.despine()

subplot(1,2,2)
sns.barplot(data=results, x='File format', y='File size [MB]',
            dodge=False, alpha=1, ax=gca(), color='C0')

plt.title('File size [MB]')
plt.xticks(rotation=30)
plt.grid(lw=0.2)
plt.annotate('b)', xy=(-0.1, 1.1), xycoords='axes fraction', fontsize=12, fontweight='bold')
plt.tight_layout()
sns.despine()

sf('results', NAME, dpi=300)
# Out:
# /tmp/ipykernel_2666089/172240692.py:29: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Saved: /media/faststorage/Projects/230508-sw__mint-publication/data-formats/output/230822-sw__MINT-v0.3.3-benchmark/pdf/230822-sw__MINT-v0.3.pdf
# Saved: /media/faststorage/Projects/230508-sw__mint-publication/data-formats/output/230822-sw__MINT-v0.3.3-benchmark/png/230822-sw__MINT-v0.3.png
# Saved: /media/faststorage/Projects/230508-sw__mint-publication/data-formats/output/230822-sw__MINT-v0.3.3-benchmark/svg/230822-sw__MINT-v0.3.svg
